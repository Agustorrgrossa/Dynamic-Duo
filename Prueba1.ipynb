# %% [markdown]
# <a href="https://colab.research.google.com/github/Agustorrgrossa/Dynamic-Duo/blob/main/Prueba1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Clase 1 8-11.mp4',
#  'Clase 2 10-11.mp4',
#  'Clase 3 15- 11 Sentencia If, Else y Elif.mp4',
#  'Clase 4 17- 11 Bucle While y For.mp4',
#  'Clase 5 22- 11 video complementario 1 else en sentencia try - except.mp4',
#  'Clase 5 22-11 sentencia try - except y funciones.mp4',
#  'Clase 5 22- 11 Argumentos por valor y referencia.mp4',
#  'Clase 5 22- 11 Funciones lambdas o anonimas.mp4',
#  'Clase 5 22- 11 Argumentar funciones y su importancia.mp4',
#  'Henry',
#  'Henry Cursado',
#  'Proyecto_Integrador_3.drawio.svg',
#  'MockUp.gslides',
#  'Colab Notebooks',
#  'game.csv']

# %%
data = "/content/drive/MyDrive/game.csv"
df_data = pd.read_csv(data)
df_data.head()
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# 0  24600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0  ...
# 1  24600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0  ...
# 2  24600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0  ...
# 3  24600004  1946-11-02 00:00:00  CHS vs. NYK       W    0      21.0  ...
# 4  24600005  1946-11-02 00:00:00  DEF vs. WAS       L    0      10.0  ...
#
# ...
